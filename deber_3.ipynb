# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import psycopg2

# %%
df = pd.read_csv('./Phishing_Legitimate_full.csv', delimiter=',')
print (df.shape)
# Out:
# (10000, 50)

# %%
print(df.head)
# Out:
# <bound method NDFrame.head of          id  NumDots  SubdomainLevel  PathLevel  UrlLength  NumDash  \
# 0         1        3               1          5         72        0
# 1         2        3               1          3        144        0
# 2         3        3               1          2         58        0
# 3         4        3               1          6         79        1
# 4         5        3               0          4         46        0
# ...     ...      ...             ...        ...        ...      ...
# 9995   9996        3               1          1         50        0
# 9996   9997        2               1          4         59        1
# 9997   9998        2               1          4         57        0
# 9998   9999        3               1          1         49        0
# 9999  10000        3               1          2         52        3
#
#       NumDashInHostname  AtSymbol  TildeSymbol  NumUnderscore  ...  \
# ...

# %%
print (df.isnull().sum())
# Out:
# id                                    0
# NumDots                               0
# SubdomainLevel                        0
# PathLevel                             0
# UrlLength                             0
# NumDash                               0
# NumDashInHostname                     0
# AtSymbol                              0
# TildeSymbol                           0
# NumUnderscore                         0
# NumPercent                            0
# NumQueryComponents                    0
# NumAmpersand                          0
# NumHash                               0
# NumNumericChars                       0
# NoHttps                               0
# RandomString                          0
# IpAddress                             0
# DomainInSubdomains                    0
# DomainInPaths                         0
# HttpsInHostname                       0
# HostnameLength                        0
# PathLength                            0
# ...

# %%
print (df.dtypes)
# Out:
# id                                      int64
# NumDots                                 int64
# SubdomainLevel                          int64
# PathLevel                               int64
# UrlLength                               int64
# NumDash                                 int64
# NumDashInHostname                       int64
# AtSymbol                                int64
# TildeSymbol                             int64
# NumUnderscore                           int64
# NumPercent                              int64
# NumQueryComponents                      int64
# NumAmpersand                            int64
# NumHash                                 int64
# NumNumericChars                         int64
# NoHttps                                 int64
# RandomString                            int64
# IpAddress                               int64
# DomainInSubdomains                      int64
# DomainInPaths                           int64
# ...

# %%
df=df.apply(lambda x: x.str.lower() if x.dtype=="object" else x)

# %%
print((df=="unknow").sum())
# Out:
# id                                    0
# NumDots                               0
# SubdomainLevel                        0
# PathLevel                             0
# UrlLength                             0
# NumDash                               0
# NumDashInHostname                     0
# AtSymbol                              0
# TildeSymbol                           0
# NumUnderscore                         0
# NumPercent                            0
# NumQueryComponents                    0
# NumAmpersand                          0
# NumHash                               0
# NumNumericChars                       0
# NoHttps                               0
# RandomString                          0
# IpAddress                             0
# DomainInSubdomains                    0
# DomainInPaths                         0
# HttpsInHostname                       0
# HostnameLength                        0
# PathLength                            0
# ...

# %%
print((df=="na").sum())
# Out:
# id                                    0
# NumDots                               0
# SubdomainLevel                        0
# PathLevel                             0
# UrlLength                             0
# NumDash                               0
# NumDashInHostname                     0
# AtSymbol                              0
# TildeSymbol                           0
# NumUnderscore                         0
# NumPercent                            0
# NumQueryComponents                    0
# NumAmpersand                          0
# NumHash                               0
# NumNumericChars                       0
# NoHttps                               0
# RandomString                          0
# IpAddress                             0
# DomainInSubdomains                    0
# DomainInPaths                         0
# HttpsInHostname                       0
# HostnameLength                        0
# PathLength                            0
# ...

# %%
df=df.replace(["unknown","na",None],np.nan)

# %%
df.dropna(inplace=True)

# %%
# Paso 1: Crear la base de datos y la tabla desde Python
def create_database_and_table():
    try:
        # Conexión al servidor PostgreSQL (sin especificar una base de datos)
        conn = psycopg2.connect(
            user="postgres", # Usuario predeterminado
            password="postgres",
            host="localhost",
            port="5432"
        )
        conn.autocommit = True # Necesario para crear una base de datos
        cursor = conn.cursor()

        # Crear la base de datos "pishing_logs" si no existe
        cursor.execute("SELECT datname FROM pg_database WHERE datname='pishing_logs';")
        if not cursor.fetchone():
            cursor.execute("CREATE DATABASE cpishing_logs;")
            print("Base de datos 'pishing_logs' creada correctamente.")
        else:
            print("La base de datos 'pishing_logs' ya existe.")

        # Cerrar la conexión inicial
        cursor.close()
        conn.close()

        # Conectar a la nueva base de datos
        conn = psycopg2.connect(
            database="pishing_logs",
            user="postgres",
            password="postgres",
            host="localhost",
            port="5432"
        )
        cursor = conn.cursor()

        # Crear la tabla "pishing_data" si no existe
        cursor.execute("""
            CREATE TABLE IF NOT EXISTS pishing_data (
            id SERIAL PRIMARY KEY,
            timestamp TIMESTAMP NOT NULL,
            ip_address VARCHAR(15),
            event_type VARCHAR(50),
            description TEXT
        );
        """)
        print("Tabla 'pishing_data' creada correctamente.")

        # Confirmar cambios y cerrar la conexión
        conn.commit()
        cursor.close()
        conn.close()

    except Exception as e:
        print(f"Error al crear la base de datos o la tabla: {e}")

# Paso 2: Insertar datos estructurados en la tabla
def insert_pishing_data():
    try:
        # Conectar a la base de datos
        conn = psycopg2.connect(
            database="pishing_logs",
            user="postgres",
            password="postgres",
            host="localhost",
            port="5432"
        )
        cursor = conn.cursor()

        # Datos de ejemplo para insertar los primeros 10 logs
        logs = df[:10] 

        #Definir la variable columns
        columns = list(logs.columns) #si falla reemplazar por: [nombre_columna1,nombre_columna2,...]

        # Datos pasar a tuplas
        logs = [tuple(x) for x in logs[columns].to_records(index=False)]


        # Insertar registros en la tabla
        cursor.executemany("""
        INSERT INTO pishing_data (timestamp, ip_address, event_type, description)
        VALUES (%s, %s, %s, %s);
        """, logs)

        # Confirmar cambios y cerrar la conexión
        conn.commit()
        print("Datos estructurados insertados correctamente.")
        cursor.close()
        conn.close()

    except Exception as e:
        print(f"Error al insertar datos estructurados: {e}")
